# %% [markdown]
# Forbes World's Billionaires List 2022
# The world's richest in 2022

# %% [markdown]
# About Dataset
# The richest in 2022
# Data source: https://www.forbes.com/billionaires/
#
# Cover image credit: https://www.pexels.com/photo/100-us-dollar-banknotes-3483098/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('forbes_2022_billionaires.csv',index_col=0)#Making the first column the index column
dataset.head()
# Out:
#                     personName   age  finalWorth  year  month  \
# rank
# 1                    Elon Musk  50.0      219000  2022      4
# 2                   Jeff Bezos  58.0      171000  2022      4
# 3     Bernard Arnault & family  73.0      158000  2022      4
# 4                   Bill Gates  66.0      129000  2022      4
# 5               Warren Buffett  91.0      118000  2022      4
#
#                    category              source        country       state  \
# rank
# 1                Automotive       Tesla, SpaceX  United States       Texas
# 2                Technology              Amazon  United States  Washington
# 3          Fashion & Retail                LVMH         France         NaN
# 4                Technology           Microsoft  United States  Washington
# 5     Finance & Investments  Berkshire Hathaway  United States    Nebraska
#
#          city  ... selfMade gender   birthDate             title  \
# rank           ...
# ...

# %%
dataset.columns
# Out:
# Index(['personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio', 'about',
#        'Age(updated)'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#                age     finalWorth    year   month  philanthropyScore  \
# count  2582.000000    2668.000000  2668.0  2668.0         396.000000
# mean     64.210689    4762.350075  2022.0     4.0           1.856061
# std      13.401258   10540.482258     0.0     0.0           0.971486
# min      19.000000    1000.000000  2022.0     4.0           1.000000
# 25%      55.000000    1500.000000  2022.0     4.0           1.000000
# 50%      64.000000    2400.000000  2022.0     4.0           2.000000
# 75%      74.000000    4300.000000  2022.0     4.0           2.000000
# max     100.000000  219000.000000  2022.0     4.0           5.000000
#
#        numberOfSiblings  Age(updated)
# count        127.000000   2668.000000
# mean           2.732283     66.511994
# std            1.891706     17.088826
# min            1.000000     19.000000
# 25%            2.000000     56.000000
# 50%            2.000000     65.000000
# 75%            3.000000     75.000000
# ...

# %%
dataset.tail()
# Out:
#                    personName   age  finalWorth  year  month       category  \
# rank
# 2578            Zhang Yuqiang  66.0        1000  2022      4  Manufacturing
# 2578               Zhou Ruxin  59.0        1000  2022      4     Technology
# 2578        Wen Zhou & family  57.0        1000  2022      4  Manufacturing
# 2578     Zhou Yifeng & family  43.0        1000  2022      4         Energy
# 2578  Zhuang Kuilong & family  59.0        1000  2022      4  Manufacturing
#
#                        source country state          city  ... selfMade  \
# rank                                                       ...
# 2578               Fiberglass   China   NaN     Tongxiang  ...     True
# 2578               Navigation   China   NaN       Beijing  ...     True
# 2578                chemicals   China   NaN      Shanghai  ...     True
# 2578  liquefied petroleum gas   China   NaN  Zhangjiagang  ...     True
# 2578                polyester   China   NaN       Jiaxing  ...     True
#
# ...

# %% [markdown]
# Picture above shows there are 2579 rows in total(Note:Its 2579 because the index starts from zero)

# %%
dataset.iloc[6]#Access all information about a row through index number of the row
# Out:
# personName                                                    Sergey Brin
# age                                                                    48
# finalWorth                                                         107000
# year                                                                 2022
# month                                                                   4
# category                                                       Technology
# source                                                             Google
# country                                                     United States
# state                                                          California
# city                                                            Los Altos
# countryOfCitizenship                                        United States
# organization                                                     Alphabet
# selfMade                                                             True
# ...

# %%
dataset.isna().sum()
# Out:
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# Age(updated)               0
# dtype: int64

# %% [markdown]
# Null Values - available in the following columns:age,country,state,city,organization,gender,birthdate,title,philantropyScore,residenceMsa,number of siblings,bio,about.

# %%
del dataset['state']

# %%
dataset['country']
# Out:
# rank
# 1       United States
# 2       United States
# 3              France
# 4       United States
# 5       United States
#             ...
# 2578            China
# 2578            China
# 2578            China
# 2578            China
# 2578            China
# Name: country, Length: 2668, dtype: object

# %%
del dataset['city']

# %%
del dataset['organization']

# %%
del dataset['title']

# %%
del dataset['bio']

# %%
del dataset['numberOfSiblings']

# %%
del dataset['residenceMsa']

# %%
dataset.tail()
# Out:
#                    personName   age  finalWorth  year  month       category  \
# rank
# 2578            Zhang Yuqiang  66.0        1000  2022      4  Manufacturing
# 2578               Zhou Ruxin  59.0        1000  2022      4     Technology
# 2578        Wen Zhou & family  57.0        1000  2022      4  Manufacturing
# 2578     Zhou Yifeng & family  43.0        1000  2022      4         Energy
# 2578  Zhuang Kuilong & family  59.0        1000  2022      4  Manufacturing
#
#                        source country countryOfCitizenship  selfMade gender  \
# rank
# 2578               Fiberglass   China                China      True      M
# 2578               Navigation   China                China      True      M
# 2578                chemicals   China                China      True      M
# 2578  liquefied petroleum gas   China                China      True      F
# 2578                polyester   China                China      True      M
#
# ...

# %%
del dataset['about']

# %%
del dataset['age']

# %%
del dataset['birthDate']

# %%
dataset.isna().sum()
# Out:
# personName                 0
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# countryOfCitizenship       0
# selfMade                   0
# gender                    16
# philanthropyScore       2272
# Age(updated)               0
# dtype: int64

# %%
#Replacing missing values with either mean, mode or median

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset
# Out:
#                     personName  finalWorth  year  month  \
# rank
# 1                    Elon Musk      219000  2022      4
# 2                   Jeff Bezos      171000  2022      4
# 3     Bernard Arnault & family      158000  2022      4
# 4                   Bill Gates      129000  2022      4
# 5               Warren Buffett      118000  2022      4
# ...                        ...         ...   ...    ...
# 2578             Zhang Yuqiang        1000  2022      4
# 2578                Zhou Ruxin        1000  2022      4
# 2578         Wen Zhou & family        1000  2022      4
# 2578      Zhou Yifeng & family        1000  2022      4
# 2578   Zhuang Kuilong & family        1000  2022      4
#
#                    category                   source        country  \
# rank
# 1                Automotive            Tesla, SpaceX  United States
# 2                Technology                   Amazon  United States
# 3          Fashion & Retail                     LVMH         France
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2668 entries, 1 to 2578
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   personName            2668 non-null   object
#  1   finalWorth            2668 non-null   int64
#  2   year                  2668 non-null   int64
#  3   month                 2668 non-null   int64
#  4   category              2668 non-null   object
#  5   source                2668 non-null   object
#  6   country               2655 non-null   object
#  7   countryOfCitizenship  2668 non-null   object
#  8   selfMade              2668 non-null   bool
#  9   gender                2652 non-null   object
#  10  philanthropyScore     396 non-null    float64
#  11  Age(updated)          2668 non-null   int64
# dtypes: bool(1), float64(1), int64(4), object(6)
# memory usage: 252.7+ KB

# %%
dataset['country'].equals(dataset['countryOfCitizenship'])
# Out:
# False

# %%
import string

# %%
dataset['gender'].fillna('No Gender', inplace=True)

# %%
dataset['philanthropyScore'].fillna(int(dataset['philanthropyScore'].mean()), inplace=True)

# %%
dataset['country'].interpolate(method='linear', direction = 'forward', inplace=True)

# %%
dataset.isna().sum()
# Out:
# personName               0
# finalWorth               0
# year                     0
# month                    0
# category                 0
# source                   0
# country                 13
# countryOfCitizenship     0
# selfMade                 0
# gender                   0
# philanthropyScore        0
# Age(updated)             0
# dtype: int64

# %%
newdataset = dataset.dropna()

# %%
newdataset.isna().sum()
# Out:
# personName              0
# finalWorth              0
# year                    0
# month                   0
# category                0
# source                  0
# country                 0
# countryOfCitizenship    0
# selfMade                0
# gender                  0
# philanthropyScore       0
# Age(updated)            0
# dtype: int64

# %%
#Data is clean ready for Visualization : Power Bi / Seaborn

# %%
newdataset
# Out:
#                     personName  NetWorth($ Billion)  year  month  \
# rank
# 1                    Elon Musk               219000  2022      4
# 2                   Jeff Bezos               171000  2022      4
# 3     Bernard Arnault & family               158000  2022      4
# 4                   Bill Gates               129000  2022      4
# 5               Warren Buffett               118000  2022      4
# ...                        ...                  ...   ...    ...
# 2578             Zhang Yuqiang                 1000  2022      4
# 2578                Zhou Ruxin                 1000  2022      4
# 2578         Wen Zhou & family                 1000  2022      4
# 2578      Zhou Yifeng & family                 1000  2022      4
# 2578   Zhuang Kuilong & family                 1000  2022      4
#
#                    industry                   source        country  \
# rank
# 1                Automotive            Tesla, SpaceX  United States
# ...

# %%
newdataset.rename(columns = {'finalWorth':'NetWorth($ Billion)', 'category':'industry'}, inplace = True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
newdataset
# Out:
#                     personName  NetWorth($ Billion)  year  month  \
# rank
# 1                    Elon Musk               219000  2022      4
# 2                   Jeff Bezos               171000  2022      4
# 3     Bernard Arnault & family               158000  2022      4
# 4                   Bill Gates               129000  2022      4
# 5               Warren Buffett               118000  2022      4
# ...                        ...                  ...   ...    ...
# 2578             Zhang Yuqiang                 1000  2022      4
# 2578                Zhou Ruxin                 1000  2022      4
# 2578         Wen Zhou & family                 1000  2022      4
# 2578      Zhou Yifeng & family                 1000  2022      4
# 2578   Zhuang Kuilong & family                 1000  2022      4
#
#                    industry                   source        country  \
# rank
# 1                Automotive            Tesla, SpaceX  United States
# ...

# %%
newdataset.describe()
# Out:
#        NetWorth($ Billion)    year   month  philanthropyScore  Age(updated)
# count          2655.000000  2655.0  2655.0        2655.000000   2655.000000
# mean           4765.517891  2022.0     4.0           1.127684     66.418079
# std           10557.577193     0.0     0.0           0.483221     16.873861
# min            1000.000000  2022.0     4.0           1.000000     25.000000
# 25%            1500.000000  2022.0     4.0           1.000000     56.000000
# 50%            2400.000000  2022.0     4.0           1.000000     65.000000
# 75%            4300.000000  2022.0     4.0           1.000000     75.000000
# max          219000.000000  2022.0     4.0           5.000000    122.000000

# %%
newdataset.columns
# Out:
# Index(['personName', 'NetWorth($ Billion)', 'year', 'month', 'industry',
#        'source', 'country', 'countryOfCitizenship', 'selfMade', 'gender',
#        'philanthropyScore', 'Age(updated)'],
#       dtype='object')

# %%
newdataset.columns
# Out:
# Index(['Name', 'NetWorth($ Billion)', 'year', 'month', 'industry', 'source',
#        'country', 'countryOfCitizenship', 'selfMade', 'gender',
#        'philanthropyScore', 'Age(updated)'],
#       dtype='object')

# %% [markdown]
# Things to check for: In the above dataset
# 1.Who are the Top 10 richest in the world

# %%
newdataset.head()
# Out:
#                           Name  NetWorth($ Billion)  year  month  \
# rank
# 1                    Elon Musk               219000  2022      4
# 2                   Jeff Bezos               171000  2022      4
# 3     Bernard Arnault & family               158000  2022      4
# 4                   Bill Gates               129000  2022      4
# 5               Warren Buffett               118000  2022      4
#
#                    industry              source        country  \
# rank
# 1                Automotive       Tesla, SpaceX  United States
# 2                Technology              Amazon  United States
# 3          Fashion & Retail                LVMH         France
# 4                Technology           Microsoft  United States
# 5     Finance & Investments  Berkshire Hathaway  United States
#
#      countryOfCitizenship  selfMade gender  philanthropyScore  Age(updated)
# rank
# 1           United States      True      M                1.0            50
# ...

# %%
fig,ax=plt.subplots()#function that returns a tuple containing a figure and axes object(s)
ax.bar(newdataset['Name'][:10],newdataset['NetWorth($ Billion)'][:10])
[s.set_visible(False) for s in ax.spines.values()]
ax.set_title('Top 10 Billionares on Forbes')
ax.set_ylabel('NetWorth($ Billion)')
ax.set_xticklabels(labels=newdataset['Name'][:11],rotation=90)
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()

# %% [markdown]
# 2.Which country has the highest number of billionares

# %%
newdataset['country'].unique()#check the countries involved
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Argentina', 'Ireland', 'Bermuda',
#        'Lebanon', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
len(newdataset['country'].unique())#Know the total number of unique countries
# Out:
# 73

# %%
newdataset.groupby('country').size()#returns count of each unique country on the list
# Out:
# country
# Algeria                   1
# Andorra                   1
# Argentina                 6
# Australia                41
# Austria                  12
#                        ...
# United Arab Emirates     10
# United Kingdom           85
# United States           748
# Uruguay                   3
# Vietnam                   7
# Length: 73, dtype: int64

# %%
country_counts=newdataset.groupby('country').size()#saving it to a new variable

# %%
country_counts=country_counts.to_frame()#convert data into dataframe

# %%
country_counts=country_counts.rename(columns={0:'count'})#change the name of the count column from zero

# %%
country_counts=country_counts.sort_values(by='count',ascending= False)#sort values in descending form

# %%
country_counts
# Out:
#                 count
# country
# United States     748
# China             571
# India             159
# Germany           112
# United Kingdom     85
# ...               ...
# Andorra             1
# Liechtenstein       1
# Nepal               1
# Oman                1
# Algeria             1
#
# [73 rows x 1 columns]

# %%
fig,ax1=plt.subplots()#function that returns a tuple containing a figure and axes object(s)
ax1.bar(country_counts.index[:10],country_counts['count'][:10])
[s.set_visible(False) for s in ax1.spines.values()]
ax1.set_title('Countries per count of Billionare')
ax1.set_ylabel('Number of billionares per country')
ax1.set_xticklabels(labels=country_counts.index,rotation=90)
plt.grid(axis='y',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# Who is the richest in Africa

# %%
Africa=['Algeria','Angola','Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon','Central African Republic','Chad','Comoros','Congo, Democratic Republic of the Congo',"Republic of the Cote d'Ivoire",'Djibouti','Egypt','Equatorial Guinea','Eritrea','Eswatini','Ethiopia','Gabon','Gambia','Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Libya','Madagascar','Malawi','Mali','Mauritania','Mauritius','Morocco','Mozambique','Namibia','Niger','Nigeria','Rwanda','Sao Tome and Principe','Senegal','Seychelles','Sierra Leone','Somalia','South Africa','South Sudan','Sudan','Tanzania','Togo','Tunisia','Uganda','Zambia','Zimbabwe']

# %%
Africa
# Out:
# ['Algeria',
#  'Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  'Congo, Democratic Republic of the Congo',
#  "Republic of the Cote d'Ivoire",
#  'Djibouti',
#  'Egypt',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Eswatini',
#  'Ethiopia',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Morocco',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Sudan',
#  'Tanzania',
#  'Togo',
#  'Tunisia',
#  'Uganda',
#  'Zambia',
#  'Zimbabwe']

# %%
country_in_list=[]
for country in Africa:
    if country in country_counts.index:
        country_in_list.append(country)

# %%
 country_in_list
# Out:
# ['Algeria', 'Egypt', 'Morocco', 'Nigeria', 'South Africa', 'Tanzania']

# %% [markdown]
# The country withe highest count would be:

# %%
country_counts.loc[country_in_list]#To access specific rows by index names in the Country_count dataframe
# Out:
#               count
# country
# Algeria           1
# Egypt             5
# Morocco           2
# Nigeria           3
# South Africa      5
# Tanzania          1

# %% [markdown]
# The 10 richest in Africa

# %%
newdatsetafrica=newdataset.set_index(keys='country')

# %%
newdatsetafrica=newdatsetafrica.loc[country_in_list]

# %%
newdatsetafrica=newdatsetafrica.sort_values(by='NetWorth($ Billion)',ascending=False)

# %%
import seaborn as sns

# %%
fig,ax5=plt.subplots(figsize=(7,5))
sns.barplot(newdatsetafrica['Name'][:10],newdatsetafrica['NetWorth($ Billion)'][:10],hue=newdatsetafrica.index[:10],dodge=False)
[s.set_visible(False) for s in ax5.spines.values()]
ax5.set_title('Top 10 richest in africa')
ax5.set_xlabel('Country')
ax5.set_xticklabels(newdatsetafrica['Name'][:10],rotation=90)
ax5.legend(fontsize=7,loc='upper right')
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()

# %% [markdown]
# Which industry has the highest number of billionares

# %%
newdataset['industry'].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion & Retail',
#        'Finance & Investments', 'Diversified', 'Media & Entertainment',
#        'Telecom', 'Food & Beverage', 'Logistics', 'Real Estate',
#        'Metals & Mining', 'Manufacturing', 'Gambling & Casinos',
#        'Healthcare', 'Service', 'Energy', 'Construction & Engineering',
#        'Sports'], dtype=object)

# %%
#newdataset['industry']=newdataset['industry'].apply(lambda x:x.replace('',''))-error(wanted to replace blank spaces with nothing)

# %%
newdataset.groupby('industry').size()
# Out:
# industry
# Automotive                     69
# Construction & Engineering     46
# Diversified                   180
# Energy                         95
# Fashion & Retail              247
# Finance & Investments         390
# Food & Beverage               202
# Gambling & Casinos             23
# Healthcare                    217
# Logistics                      35
# Manufacturing                 334
# Media & Entertainment          98
# Metals & Mining                68
# Real Estate                   193
# Service                        53
# Sports                         27
# Technology                    341
# Telecom                        37
# dtype: int64

# %%
Industry_count=newdataset.groupby('industry').size()

# %%
Industry_count=Industry_count.to_frame()

# %%
Industry_count=Industry_count.rename(columns={0:'count'})

# %%
Industry_count=Industry_count.sort_values(by='count',ascending= False)

# %%
Industry_count
# Out:
#                             count
# industry
# Finance & Investments         390
# Technology                    341
# Manufacturing                 334
# Fashion & Retail              247
# Healthcare                    217
# Food & Beverage               202
# Real Estate                   193
# Diversified                   180
# Media & Entertainment          98
# Energy                         95
# Automotive                     69
# Metals & Mining                68
# Service                        53
# Construction & Engineering     46
# Telecom                        37
# Logistics                      35
# Sports                         27
# Gambling & Casinos             23

# %%
fig,ax2=plt.subplots()
[s.set_visible(False) for s in ax2.spines.values()]
ax2.barh(Industry_count.index,Industry_count['count'])
ax2.set_title('Industries per count of Billionare')
ax2.set_xlabel('Count of billionares')
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()

# %%
 #Relationship between age and wealth

# %% [raw]
# Scatterplot- Relationship is between two numerical data

# %%
fig,ax3=plt.subplots(figsize=(10,5))
[s.set_visible(False) for s in ax3.spines.values()]
ax3.scatter(newdataset['Age(updated)'],newdataset['NetWorth($ Billion)'],color='green')
ax3.set_xlabel('Age(updated)')
ax3.set_ylabel('NetWorth($ Billion)')
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()

# %% [markdown]
# This shows there is no relationship between age and money

# %%
newdataset.columns
# Out:
# Index(['Name', 'NetWorth($ Billion)', 'year', 'month', 'industry', 'source',
#        'country', 'countryOfCitizenship', 'selfMade', 'gender',
#        'philanthropyScore', 'Age(updated)'],
#       dtype='object')

# %% [markdown]
# Distribution of Age

# %%
fig,ax4=plt.subplots(figsize=(6,5))
[s.set_visible(False) for s in ax4.spines.values()]
ax4.hist(newdataset['Age(updated)'])
ax4.set_xlabel('Age(updated)')
ax4.set_title('Distribution of Age')
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()

# %% [markdown]
# The graph shows a unimodal distribution and even looks like a norminal distribution.The age group 50-70 years seems to have the highest frequency in the dataset.Also seems like there are more older people in the dataset.

# %% [markdown]
# The Youngest Billionare(s)

# %%
By_Age=newdataset.sort_values(by ="Age(updated)",ascending=True)

# %%
By_Age
# Out:
#                       Name  NetWorth($ Billion)  year  month  \
# rank
# 1929           Wang Zelong                 1500  2022      4
# 2190    Alexandra Andresen                 1300  2022      4
# 1929      Pedro Franceschi                 1500  2022      4
# 1929     Henrique Dubugras                 1500  2022      4
# 1818        Austin Russell                 1600  2022      4
# ...                    ...                  ...   ...    ...
# 1929       Tadako Nakatani                 1500  2022      4
# 2448        Michael McCain                 1100  2022      4
# 2448     Gabriella Meister                 1100  2022      4
# 1053         Benjamin Otto                 2900  2022      4
# 336   Zhou Qunfei & family                 7100  2022      4
#
#                    industry                        source        country  \
# rank
# 1929        Metals & Mining                     chemicals          China
# ...

# %%
fig,ax8=plt.subplots(figsize=(7,5))
sns.barplot(By_Age['Name'][:10],By_Age['Age(updated)'][:10],hue=By_Age['country'][:10],dodge=False)
[s.set_visible(False) for s in ax8.spines.values()]
ax8.set_title('Youngest billionares on Forbes')
ax8.set_xlabel('Age')
ax8.set_xticklabels(labels=By_Age['Name'][:10],rotation=90)
ax8.legend(fontsize=7,loc='upper left')
plt.grid(axis='y',linestyle='--',linewidth=0.3)
plt.show()
